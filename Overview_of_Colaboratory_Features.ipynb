# %% [markdown]
# <a href="https://colab.research.google.com/github/jiriyaporn/DATA_TEST_MODAL/blob/main/Overview_of_Colaboratory_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###TEST DATA
# forecast regression

# %% [markdown]
# ### test model
# #treatment  call PTP DBO SPECIAL OA

# %%
import numpy as np
import pandas as pd

# %%
pip install requests

# %%
import requests
import time

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/Project64'
kiv = os.path.join(path, 'Collection Performance by Lots.csv')

# %%
data = os.path.join(path, 'Collection Performance by Lots.csv')
print(data)
data_kiv = pd.read_csv(data)
kiv = data_kiv
kiv
# Out:
# /content/drive/My Drive/Project64/Collection Performance by Lots.csv
#      LegalVintage  Monthly  Total Collection  Cash Collection  DPO Collection  \
# 0         2004-03  2024-01               0.0              0.0             0.0
# 1         2004-03  2024-02               0.0              0.0             0.0
# 2         2004-03  2024-03               0.0              0.0             0.0
# 3         2004-03  2024-04               0.0              0.0             0.0
# 4         2004-03  2024-05               0.0              0.0             0.0
# ...           ...      ...               ...              ...             ...
# 6112      2026-05  2026-01            2500.0           2500.0             0.0
# 6113      2026-05  2026-02            2000.0           2000.0             0.0
# 6114      2026-05  2026-03            3500.0           3500.0             0.0
# 6115      2026-05  2026-04            6500.0           6500.0             0.0
# ...

# %%
print(kiv)
# Out:
#      LegalVintage  Monthly  Total Collection  Cash Collection  DPO Collection  \
# 0         2004-03  2024-01               0.0              0.0             0.0
# 1         2004-03  2024-02               0.0              0.0             0.0
# 2         2004-03  2024-03               0.0              0.0             0.0
# 3         2004-03  2024-04               0.0              0.0             0.0
# 4         2004-03  2024-05               0.0              0.0             0.0
# ...           ...      ...               ...              ...             ...
# 6112      2026-05  2026-01            2500.0           2500.0             0.0
# 6113      2026-05  2026-02            2000.0           2000.0             0.0
# 6114      2026-05  2026-03            3500.0           3500.0             0.0
# 6115      2026-05  2026-04            6500.0           6500.0             0.0
# 6116      2026-05  2026-05            5000.0           5000.0             0.0
#
# ...

# %%
# !pip install prophet

# %%
from prophet import Prophet

# %%
data = kiv[['Total Collection',	'Cash Collection',	'DPO Collection',	'Active Principal',	'Active Pay Principal',
            'Closed Principal',	'DPO Marginal Principal',	'%DPO Recovery']]

# %%
import pandas as pd
from statsmodels.tsa.api import VAR

# %%
print(data.dtypes)
# Out:
# Total Collection          float64
# Cash Collection           float64
# DPO Collection            float64
# Active Principal          float64
# Active Pay Principal      float64
# Closed Principal          float64
# DPO Marginal Principal    float64
# %DPO Recovery              object
# dtype: object

# %%
data = data.apply(pd.to_numeric, errors='coerce')

# %%
data = data.fillna(1)

# %%
for i, col in enumerate(data.columns):
    print(i, col, data[col].nunique())
# Out:
# 0 Total Collection 2174
# 1 Cash Collection 1777
# 2 DPO Collection 814
# 3 Active Principal 1839
# 4 Active Pay Principal 2924
# 5 Closed Principal 1231
# 6 DPO Marginal Principal 1231
# 7 %DPO Recovery 1

# %%
data = data.loc[:, data.nunique() > 1]

# %%
model = VAR(data)

model_fit = model.fit()

# %%
print(data.corr())
# Out:
#                         Total Collection  Cash Collection  DPO Collection  \
# Total Collection                1.000000         0.728792        0.892852
# Cash Collection                 0.728792         1.000000        0.342333
# DPO Collection                  0.892852         0.342333        1.000000
# Active Principal                0.506626         0.572546        0.318618
# Active Pay Principal            0.667907         0.771705        0.408937
# Closed Principal                0.844921         0.404326        0.893456
# DPO Marginal Principal          0.844921         0.404326        0.893456
#
#                         Active Principal  Active Pay Principal  \
# Total Collection                0.506626              0.667907
# Cash Collection                 0.572546              0.771705
# DPO Collection                  0.318618              0.408937
# Active Principal                1.000000              0.734661
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression

X = kiv[['Cash Collection',	'DPO Collection']]

y = kiv['Total Collection']
model = LinearRegression()

model.fit(X,y)

pred = model.predict(X)

print(pred)
# Out:
# [-1.09139364e-11 -1.09139364e-11 -1.09139364e-11 ...  3.50000000e+03
#   6.50000000e+03  5.00000000e+03]

# %%
import matplotlib.pyplot as plt

plt.scatter(kiv['Total Collection'], kiv['Cash Collection'])
plt.show()

# %%
from statsmodels.stats.stattools import durbin_watson

durbin_watson(pred)
# Out:
# np.float64(0.7350229942825717)
